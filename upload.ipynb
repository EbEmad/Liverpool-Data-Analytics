# %%
import pandas as pd
from sqlalchemy import create_engine
from pathlib import Path
folder=Path('Data/clean')
for file in folder.iterdir():
    if file.is_file():
        df = pd.read_csv(file)
        engine = create_engine("postgresql+psycopg2://user:root@localhost:5433/test_db")
        df.to_sql(f'{file.stem}', engine, if_exists='replace', index=False)
        
print("Data uploaded successfully!")
# Out:
# Data uploaded successfully!

# %%
import pandas as pd
from sqlalchemy import create_engine
from pathlib import Path

# Folder containing CSV files
folder = Path('Data/')

# MySQL connection string (replace credentials)
mysql_engine = create_engine(
    "mysql+mysqlconnector://user:root@localhost:3306/db"
)

# Loop through CSV files and load into MySQL
for file in folder.iterdir():
    if file.is_file() and file.suffix == '.csv':
        df = pd.read_csv(file)
        df.to_sql(
            name=f'{file.stem}',  # Table name = filename (without extension)
            con=mysql_engine,
            if_exists='replace',  # Options: 'replace', 'append', 'fail'
            index=False
        )
        print(f"Loaded {file.name} into MySQL table: {file.stem}")

print("✅ All data uploaded successfully to MySQL!")
# Out:
# Loaded stg_playing_time.csv into MySQL table: stg_playing_time
# Loaded stg_scores_fixtures.csv into MySQL table: stg_scores_fixtures
# Loaded stg_goalkeeping.csv into MySQL table: stg_goalkeeping
# Loaded stg_defensive_actions.csv into MySQL table: stg_defensive_actions
# Loaded stg_pass_types.csv into MySQL table: stg_pass_types
# Loaded stg_advanced_goalkeeping.csv into MySQL table: stg_advanced_goalkeeping
# Loaded stg_miscellaneous_stats.csv into MySQL table: stg_miscellaneous_stats
# Loaded stg_standard_stats.csv into MySQL table: stg_standard_stats
# Loaded stg_goal_shot_creation.csv into MySQL table: stg_goal_shot_creation
# Loaded stg_possession.csv into MySQL table: stg_possession
# Loaded stg_passing.csv into MySQL table: stg_passing
# ✅ All data uploaded successfully to MySQL!

# %% [markdown]
# ### here we need to delete from starts_starts till the end

# %%
df=pd.read_csv('./Data/raw/stg_playing_time.csv')
df.head(5)
# Out:
#   Unnamed: 0_level_0_Player Unnamed: 1_level_0_Nation Unnamed: 2_level_0_Pos  \
# 0             Mohamed Salah                    eg EGY                     FW
# 1           Virgil van Dijk                    nl NED                     DF
# 2          Ryan Gravenberch                    nl NED                     MF
# 3       Alexis Mac Allister                    ar ARG                     MF
# 4           Ibrahima Konaté                    fr FRA                     DF
#
#    Unnamed: 3_level_0_Age  Unnamed: 4_level_0_MP  Playing Time_Min  \
# 0                    32.0                     38            3371.0
# 1                    33.0                     37            3330.0
# 2                    22.0                     37            3160.0
# 3                    25.0                     35            2599.0
# 4                    25.0                     31            2560.0
#
#    Playing Time_Mn/MP  Playing Time_Min%  Playing Time_90s  Starts_Starts  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0_level_0_Player', 'Unnamed: 1_level_0_Nation',
#        'Unnamed: 2_level_0_Pos', 'Unnamed: 3_level_0_Age',
#        'Unnamed: 4_level_0_MP', 'Playing Time_Min', 'Playing Time_Mn/MP',
#        'Playing Time_Min%', 'Playing Time_90s', 'Starts_Starts',
#        'Starts_Mn/Start', 'Starts_Compl', 'Subs_Subs', 'Subs_Mn/Sub',
#        'Subs_unSub', 'Team Success_PPM', 'Team Success_onG',
#        'Team Success_onGA', 'Team Success_+/-', 'Team Success_+/-90',
#        'Team Success_On-Off', 'Team Success (xG)_onxG',
#        'Team Success (xG)_onxGA', 'Team Success (xG)_xG+/-',
#        'Team Success (xG)_xG+/-90', 'Team Success (xG)_On-Off',
#        'Unnamed: 26_level_0_Matches'],
#       dtype='object')

# %%
df = df.rename(columns={
    # General Info
    'Unnamed: 0_level_0_Player': 'Player',
    'Unnamed: 1_level_0_Nation': 'Nation',
    'Unnamed: 2_level_0_Pos': 'Position',
    'Unnamed: 3_level_0_Age': 'Age',
    'Unnamed: 4_level_0_MP': 'Matches Played',

    # Playing Time
    'Playing Time_Min': 'Minutes Played',
    'Playing Time_Mn/MP': 'Minutes per Match',
    'Playing Time_Min%': 'Minutes % of Team Total',
    'Playing Time_90s': '90s Played',

    # Starts
    'Starts_Starts': 'Starts',
    'Starts_Mn/Start': 'Minutes per Start',
    'Starts_Compl': 'Full Matches',

    # Substitutions
    'Subs_Subs': 'Sub Appearances',
    'Subs_Mn/Sub': 'Minutes per Sub',
    'Subs_unSub': 'Unused Sub Appearances',

    # Team Success (On/Off metrics)
    'Team Success_PPM': 'Points per Match',
    'Team Success_onG': 'Goals For while On',
    'Team Success_onGA': 'Goals Against while On',
    'Team Success_+/-': 'Goal Difference while On',
    'Team Success_+/-90': 'Goal Difference per 90',
    'Team Success_On-Off': 'Team +/- On vs Off',

    # Team Success (xG)
    'Team Success (xG)_onxG': 'xG while On',
    'Team Success (xG)_onxGA': 'xGA while On',
    'Team Success (xG)_xG+/-': 'xG Differential while On',
    'Team Success (xG)_xG+/-90': 'xG Differential per 90',
    'Team Success (xG)_On-Off': 'xG +/- On vs Off',

    # Matches
    'Unnamed: 26_level_0_Matches': 'Matches'
})
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# %%
df.to_csv('./Data/clean/stg_playing_time.csv', index=False)

# %%
df=pd.read_csv('./Data/raw/stg_scores_fixtures.csv')
df.head()
#not recommended
# Out:
#          Date           Time            Comp         Round  Day Venue Result  \
# 0  2024-08-17  12:30 (11:30)  Premier League   Matchweek 1  Sat  Away      W
# 1  2024-08-25  16:30 (15:30)  Premier League   Matchweek 2  Sun  Home      W
# 2  2024-09-01  16:00 (15:00)  Premier League   Matchweek 3  Sun  Away      W
# 3  2024-09-14  15:00 (14:00)  Premier League   Matchweek 4  Sat  Home      L
# 4  2024-09-17  21:00 (19:00)    Champions Lg  League phase  Tue  Away      W
#
#   GF GA         Opponent   xG  xGA Poss Attendance          Captain Formation  \
# 0  2  0     Ipswich Town  2.6  0.5   62      30014  Virgil van Dijk   4-2-3-1
# 1  2  0        Brentford  2.5  0.5   62      60017  Virgil van Dijk   4-2-3-1
# 2  3  0   Manchester Utd  1.8  1.4   47      73738  Virgil van Dijk   4-2-3-1
# 3  0  1  Nott'ham Forest  0.9  0.4   68      60344  Virgil van Dijk   4-2-3-1
# 4  3  1         it Milan  3.1  0.6   51      59826  Virgil van Dijk   4-2-3-1
#
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'xG', 'xGA', 'Poss', 'Attendance', 'Captain', 'Formation',
#        'Opp Formation', 'Referee', 'Match Report', 'Notes'],
#       dtype='object')

# %%
df = df.rename(columns={
    'Comp': 'Competition',
    'Round': 'Match Round',
    'Day': 'Weekday',
    'Venue': 'Stadium',
    'Result': 'Match Result',
    'GF': 'Goals For',
    'GA': 'Goals Against',
    'xG': 'Expected Goals',
    'xGA': 'Expected Goals Against',
    'Poss': 'Possession %',
    'Captain': 'Team Captain',
    'Opp Formation': 'Opponent Formation',
    'Referee': 'Match Referee',
    'Match Report': 'Report Link'
})
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# %%
df.to_csv('./Data/clean/stg_scores_fixtures.csv', index=False)

# %%
df=pd.read_csv('./Data/raw/stg_defensive_actions.csv')
df.head()
# Out:
#   Unnamed: 0_level_0_Player Unnamed: 1_level_0_Nation Unnamed: 2_level_0_Pos  \
# 0             Mohamed Salah                    eg EGY                     FW
# 1           Virgil van Dijk                    nl NED                     DF
# 2          Ryan Gravenberch                    nl NED                     MF
# 3       Alexis Mac Allister                    ar ARG                     MF
# 4           Ibrahima Konaté                    fr FRA                     DF
#
#    Unnamed: 3_level_0_Age  Unnamed: 4_level_0_90s  Tackles_Tkl  Tackles_TklW  \
# 0                    32.0                    37.5           21            11
# 1                    33.0                    37.0           38            20
# 2                    22.0                    35.1           69            35
# 3                    25.0                    28.9           95            58
# 4                    25.0                    28.4           40            26
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0_level_0_Player', 'Unnamed: 1_level_0_Nation',
#        'Unnamed: 2_level_0_Pos', 'Unnamed: 3_level_0_Age',
#        'Unnamed: 4_level_0_90s', 'Tackles_Tkl', 'Tackles_TklW',
#        'Tackles_Def 3rd', 'Tackles_Mid 3rd', 'Tackles_Att 3rd',
#        'Challenges_Tkl', 'Challenges_Att', 'Challenges_Tkl%',
#        'Challenges_Lost', 'Blocks_Blocks', 'Blocks_Sh', 'Blocks_Pass',
#        'Unnamed: 17_level_0_Int', 'Unnamed: 18_level_0_Tkl+Int',
#        'Unnamed: 19_level_0_Clr', 'Unnamed: 20_level_0_Err',
#        'Unnamed: 21_level_0_Matches'],
#       dtype='object')

# %%
df = df.rename(columns={
    'Unnamed: 0_level_0_Player': 'Player',
    'Unnamed: 1_level_0_Nation': 'Nation',
    'Unnamed: 2_level_0_Pos': 'Position',
    'Unnamed: 3_level_0_Age': 'Age',
    'Unnamed: 4_level_0_90s': '90s Played',

    # Tackles
    'Tackles_Tkl': 'Tackles',
    'Tackles_TklW': 'Tackles Won',
    'Tackles_Def 3rd': 'Tackles Defensive Third',
    'Tackles_Mid 3rd': 'Tackles Middle Third',
    'Tackles_Att 3rd': 'Tackles Attacking Third',

    # Challenges
    'Challenges_Tkl': 'Challenges Tackles',
    'Challenges_Att': 'Challenges Attempted',
    'Challenges_Tkl%': 'Challenges Success %',
    'Challenges_Lost': 'Challenges Lost',

    # Blocks
    'Blocks_Blocks': 'Blocks',
    'Blocks_Sh': 'Blocked Shots',
    'Blocks_Pass': 'Blocked Passes',

    # Miscellaneous
    'Unnamed: 17_level_0_Int': 'Interceptions',
    'Unnamed: 18_level_0_Tkl+Int': 'Tackles + Interceptions',
    'Unnamed: 19_level_0_Clr': 'Clearances',
    'Unnamed: 20_level_0_Err': 'Errors',
    'Unnamed: 21_level_0_Matches': 'Matches'
})
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# %%
df.to_csv('./Data/clean/stg_defensive_actions.csv', index=False)

# %%
df=pd.read_csv('./Data/raw/stg_pass_types.csv')
df.head()
# Out:
#   Unnamed: 0_level_0_Player Unnamed: 1_level_0_Nation Unnamed: 2_level_0_Pos  \
# 0             Mohamed Salah                    eg EGY                     FW
# 1           Virgil van Dijk                    nl NED                     DF
# 2          Ryan Gravenberch                    nl NED                     MF
# 3       Alexis Mac Allister                    ar ARG                     MF
# 4           Ibrahima Konaté                    fr FRA                     DF
#
#    Unnamed: 3_level_0_Age  Unnamed: 4_level_0_90s  Unnamed: 5_level_0_Att  \
# 0                    32.0                    37.5                    1263
# 1                    33.0                    37.0                    2935
# 2                    22.0                    35.1                    1927
# 3                    25.0                    28.9                    1524
# 4                    25.0                    28.4                    1905
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0_level_0_Player', 'Unnamed: 1_level_0_Nation',
#        'Unnamed: 2_level_0_Pos', 'Unnamed: 3_level_0_Age',
#        'Unnamed: 4_level_0_90s', 'Unnamed: 5_level_0_Att', 'Pass Types_Live',
#        'Pass Types_Dead', 'Pass Types_FK', 'Pass Types_TB', 'Pass Types_Sw',
#        'Pass Types_Crs', 'Pass Types_TI', 'Pass Types_CK', 'Corner Kicks_In',
#        'Corner Kicks_Out', 'Corner Kicks_Str', 'Outcomes_Cmp', 'Outcomes_Off',
#        'Outcomes_Blocks', 'Unnamed: 20_level_0_Matches'],
#       dtype='object')

# %%
df = df.rename(columns={
    'Unnamed: 0_level_0_Player': 'Player',
    'Unnamed: 1_level_0_Nation': 'Nation',
    'Unnamed: 2_level_0_Pos': 'Position',
    'Unnamed: 3_level_0_Age': 'Age',
    'Unnamed: 4_level_0_90s': '90s Played',
    'Unnamed: 5_level_0_Att': 'Passes Attempted',
    
    # Pass Types
    'Pass Types_Live': 'Live Passes',
    'Pass Types_Dead': 'Dead Ball Passes',
    'Pass Types_FK': 'Free Kick Passes',
    'Pass Types_TB': 'Through Balls',
    'Pass Types_Sw': 'Switches',
    'Pass Types_Crs': 'Crosses',
    'Pass Types_TI': 'Throw-Ins',
    'Pass Types_CK': 'Corner Kicks',
    
    # Corner Kick Types
    'Corner Kicks_In': 'Inswinging Corners',
    'Corner Kicks_Out': 'Outswinging Corners',
    'Corner Kicks_Str': 'Straight Corners',
    
    # Pass Outcomes
    'Outcomes_Cmp': 'Passes Completed',
    'Outcomes_Off': 'Offsides',
    'Outcomes_Blocks': 'Passes Blocked',

    'Unnamed: 20_level_0_Matches': 'Matches'
})

df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# %%
df.to_csv('./Data/clean/stg_pass_types.csv', index=False)

# %%
df=pd.read_csv('./Data/raw/stg_miscellaneous_stats.csv')
df.head()
# Out:
#   Unnamed: 0_level_0_Player Unnamed: 1_level_0_Nation Unnamed: 2_level_0_Pos  \
# 0             Mohamed Salah                    eg EGY                     FW
# 1           Virgil van Dijk                    nl NED                     DF
# 2          Ryan Gravenberch                    nl NED                     MF
# 3       Alexis Mac Allister                    ar ARG                     MF
# 4           Ibrahima Konaté                    fr FRA                     DF
#
#    Unnamed: 3_level_0_Age  Unnamed: 4_level_0_90s  Performance_CrdY  \
# 0                    32.0                    37.5                 1
# 1                    33.0                    37.0                 5
# 2                    22.0                    35.1                 6
# 3                    25.0                    28.9                 6
# 4                    25.0                    28.4                 5
#
#    Performance_CrdR  Performance_2CrdY  Performance_Fls  Performance_Fld  ...  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0_level_0_Player', 'Unnamed: 1_level_0_Nation',
#        'Unnamed: 2_level_0_Pos', 'Unnamed: 3_level_0_Age',
#        'Unnamed: 4_level_0_90s', 'Performance_CrdY', 'Performance_CrdR',
#        'Performance_2CrdY', 'Performance_Fls', 'Performance_Fld',
#        'Performance_Off', 'Performance_Crs', 'Performance_Int',
#        'Performance_TklW', 'Performance_PKwon', 'Performance_PKcon',
#        'Performance_OG', 'Performance_Recov', 'Aerial Duels_Won',
#        'Aerial Duels_Lost', 'Aerial Duels_Won%',
#        'Unnamed: 21_level_0_Matches'],
#       dtype='object')

# %%
df = df.rename(columns={
    'Unnamed: 0_level_0_Player': 'Player',
    'Unnamed: 1_level_0_Nation': 'Nation',
    'Unnamed: 2_level_0_Pos': 'Position',
    'Unnamed: 3_level_0_Age': 'Age',
    'Unnamed: 4_level_0_90s': '90s Played',

    # Performance stats
    'Performance_CrdY': 'Yellow Cards',
    'Performance_CrdR': 'Red Cards',
    'Performance_2CrdY': 'Second Yellow Cards',
    'Performance_Fls': 'Fouls Committed',
    'Performance_Fld': 'Fouls Drawn',
    'Performance_Off': 'Offsides',
    'Performance_Crs': 'Crosses',
    'Performance_Int': 'Interceptions',
    'Performance_TklW': 'Tackles Won',
    'Performance_PKwon': 'Penalties Won',
    'Performance_PKcon': 'Penalties Conceded',
    'Performance_OG': 'Own Goals',
    'Performance_Recov': 'Ball Recoveries',

    # Aerial Duels
    'Aerial Duels_Won': 'Aerials Won',
    'Aerial Duels_Lost': 'Aerials Lost',
    'Aerial Duels_Won%': 'Aerial Win %',

    'Unnamed: 21_level_0_Matches': 'Matches'
})
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# %%
df.to_csv('./Data/clean/stg_miscellaneous_stats.csv', index=False)

# %%
df=pd.read_csv('./Data/raw/stg_standard_stats.csv')
df.head()
# Out:
#   Unnamed: 0_level_0_Player Unnamed: 1_level_0_Nation Unnamed: 2_level_0_Pos  \
# 0             Mohamed Salah                    eg EGY                     FW
# 1           Virgil van Dijk                    nl NED                     DF
# 2          Ryan Gravenberch                    nl NED                     MF
# 3       Alexis Mac Allister                    ar ARG                     MF
# 4           Ibrahima Konaté                    fr FRA                     DF
#
#    Unnamed: 3_level_0_Age  Unnamed: 4_level_0_MP  Playing Time_Starts  \
# 0                    32.0                     38                   38
# 1                    33.0                     37                   37
# 2                    22.0                     37                   37
# 3                    25.0                     35                   30
# 4                    25.0                     31                   30
#
#    Playing Time_Min  Playing Time_90s  Performance_Gls  Performance_Ast  ...  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0_level_0_Player', 'Unnamed: 1_level_0_Nation',
#        'Unnamed: 2_level_0_Pos', 'Unnamed: 3_level_0_Age',
#        'Unnamed: 4_level_0_MP', 'Playing Time_Starts', 'Playing Time_Min',
#        'Playing Time_90s', 'Performance_Gls', 'Performance_Ast',
#        'Performance_G+A', 'Performance_G-PK', 'Performance_PK',
#        'Performance_PKatt', 'Performance_CrdY', 'Performance_CrdR',
#        'Expected_xG', 'Expected_npxG', 'Expected_xAG', 'Expected_npxG+xAG',
#        'Progression_PrgC', 'Progression_PrgP', 'Progression_PrgR',
#        'Per 90 Minutes_Gls', 'Per 90 Minutes_Ast', 'Per 90 Minutes_G+A',
#        'Per 90 Minutes_G-PK', 'Per 90 Minutes_G+A-PK', 'Per 90 Minutes_xG',
#        'Per 90 Minutes_xAG', 'Per 90 Minutes_xG+xAG', 'Per 90 Minutes_npxG',
#        'Per 90 Minutes_npxG+xAG', 'Unnamed: 33_level_0_Matches'],
#       dtype='object')

# %%
df = df.rename(columns={
    # Player Info
    'Unnamed: 0_level_0_Player': 'Player',
    'Unnamed: 1_level_0_Nation': 'Nation',
    'Unnamed: 2_level_0_Pos': 'Position',
    'Unnamed: 3_level_0_Age': 'Age',
    'Unnamed: 4_level_0_MP': 'Matches Played',

    # Playing Time
    'Playing Time_Starts': 'Starts',
    'Playing Time_Min': 'Minutes Played',
    'Playing Time_90s': '90s Played',

    # Performance
    'Performance_Gls': 'Goals',
    'Performance_Ast': 'Assists',
    'Performance_G+A': 'Goals + Assists',
    'Performance_G-PK': 'Goals (Non-Penalty)',
    'Performance_PK': 'Penalty Goals',
    'Performance_PKatt': 'Penalty Attempts',
    'Performance_CrdY': 'Yellow Cards',
    'Performance_CrdR': 'Red Cards',

    # Expected Metrics
    'Expected_xG': 'Expected Goals (xG)',
    'Expected_npxG': 'Non-Penalty xG',
    'Expected_xAG': 'Expected Assists (xAG)',
    'Expected_npxG+xAG': 'npxG + xAG',

    # Progression
    'Progression_PrgC': 'Progressive Carries',
    'Progression_PrgP': 'Progressive Passes',
    'Progression_PrgR': 'Progressive Receptions',

    # Per 90 Minutes
    'Per 90 Minutes_Gls': 'Goals per 90',
    'Per 90 Minutes_Ast': 'Assists per 90',
    'Per 90 Minutes_G+A': 'G+A per 90',
    'Per 90 Minutes_G-PK': 'Non-PK Goals per 90',
    'Per 90 Minutes_G+A-PK': 'Non-PK G+A per 90',
    'Per 90 Minutes_xG': 'xG per 90',
    'Per 90 Minutes_xAG': 'xAG per 90',
    'Per 90 Minutes_xG+xAG': 'xG+xAG per 90',
    'Per 90 Minutes_npxG': 'npxG per 90',
    'Per 90 Minutes_npxG+xAG': 'npxG+xAG per 90',

    # Matches
    'Unnamed: 33_level_0_Matches': 'Matches'
})
df.columns=[col.lower().replace(' ','_') for col in df.columns]

# %%
df.to_csv('./Data/clean/stg_standard_stats.csv', index=False)

# %%
df=pd.read_csv('./Data/raw/stg_goal_shot_creation.csv')
df.head()
# Out:
#   Unnamed: 0_level_0_Player Unnamed: 1_level_0_Nation Unnamed: 2_level_0_Pos  \
# 0             Mohamed Salah                    eg EGY                     FW
# 1           Virgil van Dijk                    nl NED                     DF
# 2          Ryan Gravenberch                    nl NED                     MF
# 3       Alexis Mac Allister                    ar ARG                     MF
# 4           Ibrahima Konaté                    fr FRA                     DF
#
#    Unnamed: 3_level_0_Age  Unnamed: 4_level_0_90s  SCA_SCA  SCA_SCA90  \
# 0                    32.0                    37.5      169       4.51
# 1                    33.0                    37.0       48       1.30
# 2                    22.0                    35.1       68       1.94
# 3                    25.0                    28.9      120       4.15
# 4                    25.0                    28.4       31       1.09
#
#    SCA Types_PassLive  SCA Types_PassDead  SCA Types_TO  ...  SCA Types_Def  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0_level_0_Player', 'Unnamed: 1_level_0_Nation',
#        'Unnamed: 2_level_0_Pos', 'Unnamed: 3_level_0_Age',
#        'Unnamed: 4_level_0_90s', 'SCA_SCA', 'SCA_SCA90', 'SCA Types_PassLive',
#        'SCA Types_PassDead', 'SCA Types_TO', 'SCA Types_Sh', 'SCA Types_Fld',
#        'SCA Types_Def', 'GCA_GCA', 'GCA_GCA90', 'GCA Types_PassLive',
#        'GCA Types_PassDead', 'GCA Types_TO', 'GCA Types_Sh', 'GCA Types_Fld',
#        'GCA Types_Def', 'Unnamed: 21_level_0_Matches'],
#       dtype='object')

# %%
df = df.rename(columns={
    # General Info
    'Unnamed: 0_level_0_Player': 'Player',
    'Unnamed: 1_level_0_Nation': 'Nation',
    'Unnamed: 2_level_0_Pos': 'Position',
    'Unnamed: 3_level_0_Age': 'Age',
    'Unnamed: 4_level_0_90s': '90s Played',

    # Shot-Creating Actions (SCA)
    'SCA_SCA': 'SCA Total',
    'SCA_SCA90': 'SCA per 90',
    'SCA Types_PassLive': 'SCA: Live Pass',
    'SCA Types_PassDead': 'SCA: Dead Ball Pass',
    'SCA Types_TO': 'SCA: Take-Ons',
    'SCA Types_Sh': 'SCA: Shots',
    'SCA Types_Fld': 'SCA: Fouls Drawn',
    'SCA Types_Def': 'SCA: Defensive Actions',

    # Goal-Creating Actions (GCA)
    'GCA_GCA': 'GCA Total',
    'GCA_GCA90': 'GCA per 90',
    'GCA Types_PassLive': 'GCA: Live Pass',
    'GCA Types_PassDead': 'GCA: Dead Ball Pass',
    'GCA Types_TO': 'GCA: Take-Ons',
    'GCA Types_Sh': 'GCA: Shots',
    'GCA Types_Fld': 'GCA: Fouls Drawn',
    'GCA Types_Def': 'GCA: Defensive Actions',

    # Matches
    'Unnamed: 21_level_0_Matches': 'Matches'
})
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# %%
df.to_csv('./Data/clean/stg_goal_shot_creation.csv', index=False)

# %%
df=pd.read_csv('./Data/raw/stg_possession.csv')
df.head()
# Out:
#   Unnamed: 0_level_0_Player Unnamed: 1_level_0_Nation Unnamed: 2_level_0_Pos  \
# 0             Mohamed Salah                    eg EGY                     FW
# 1           Virgil van Dijk                    nl NED                     DF
# 2          Ryan Gravenberch                    nl NED                     MF
# 3       Alexis Mac Allister                    ar ARG                     MF
# 4           Ibrahima Konaté                    fr FRA                     DF
#
#    Unnamed: 3_level_0_Age  Unnamed: 4_level_0_90s  Touches_Touches  \
# 0                    32.0                    37.5             1695
# 1                    33.0                    37.0             3301
# 2                    22.0                    35.1             2343
# 3                    25.0                    28.9             1860
# 4                    25.0                    28.4             2185
#
#    Touches_Def Pen  Touches_Def 3rd  Touches_Mid 3rd  Touches_Att 3rd  ...  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0_level_0_Player', 'Unnamed: 1_level_0_Nation',
#        'Unnamed: 2_level_0_Pos', 'Unnamed: 3_level_0_Age',
#        'Unnamed: 4_level_0_90s', 'Touches_Touches', 'Touches_Def Pen',
#        'Touches_Def 3rd', 'Touches_Mid 3rd', 'Touches_Att 3rd',
#        'Touches_Att Pen', 'Touches_Live', 'Take-Ons_Att', 'Take-Ons_Succ',
#        'Take-Ons_Succ%', 'Take-Ons_Tkld', 'Take-Ons_Tkld%', 'Carries_Carries',
#        'Carries_TotDist', 'Carries_PrgDist', 'Carries_PrgC', 'Carries_1/3',
#        'Carries_CPA', 'Carries_Mis', 'Carries_Dis', 'Receiving_Rec',
#        'Receiving_PrgR', 'Unnamed: 27_level_0_Matches'],
#       dtype='object')

# %%
df = df.rename(columns={
    # General info
    'Unnamed: 0_level_0_Player': 'Player',
    'Unnamed: 1_level_0_Nation': 'Nation',
    'Unnamed: 2_level_0_Pos': 'Position',
    'Unnamed: 3_level_0_Age': 'Age',
    'Unnamed: 4_level_0_90s': '90s Played',

    # Touches
    'Touches_Touches': 'Total Touches',
    'Touches_Def Pen': 'Touches Defensive Penalty Area',
    'Touches_Def 3rd': 'Touches Defensive Third',
    'Touches_Mid 3rd': 'Touches Middle Third',
    'Touches_Att 3rd': 'Touches Attacking Third',
    'Touches_Att Pen': 'Touches Attacking Penalty Area',
    'Touches_Live': 'Live Ball Touches',

    # Take-Ons (Dribbles)
    'Take-Ons_Att': 'Take-Ons Attempted',
    'Take-Ons_Succ': 'Take-Ons Successful',
    'Take-Ons_Succ%': 'Take-Ons Success %',
    'Take-Ons_Tkld': 'Take-Ons Tackled',
    'Take-Ons_Tkld%': 'Take-Ons Tackled %',

    # Carries
    'Carries_Carries': 'Carries',
    'Carries_TotDist': 'Carry Distance (Total)',
    'Carries_PrgDist': 'Carry Distance (Progressive)',
    'Carries_PrgC': 'Progressive Carries',
    'Carries_1/3': 'Carries into Final Third',
    'Carries_CPA': 'Carries into Penalty Area',
    'Carries_Mis': 'Miscontrolled Carries',
    'Carries_Dis': 'Dispossessed on Carries',

    # Receivingdf.columns=[col.lower().replace(' ','_') for col in df.columns]
    'Receiving_Rec': 'Passes Received',
    'Receiving_PrgR': 'Progressive Passes Received',

    # Matches
    'Unnamed: 27_level_0_Matches': 'Matches'
})
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# %%
df.to_csv('./Data/clean/stg_possession.csv', index=False)

# %%
df=pd.read_csv('./Data/raw/stg_passing.csv')
df.head()
# Out:
#   Unnamed: 0_level_0_Player Unnamed: 1_level_0_Nation Unnamed: 2_level_0_Pos  \
# 0             Mohamed Salah                    eg EGY                     FW
# 1           Virgil van Dijk                    nl NED                     DF
# 2          Ryan Gravenberch                    nl NED                     MF
# 3       Alexis Mac Allister                    ar ARG                     MF
# 4           Ibrahima Konaté                    fr FRA                     DF
#
#    Unnamed: 3_level_0_Age  Unnamed: 4_level_0_90s  Total_Cmp  Total_Att  \
# 0                    32.0                    37.5        892       1263
# 1                    33.0                    37.0       2688       2935
# 2                    22.0                    35.1       1718       1927
# 3                    25.0                    28.9       1273       1524
# 4                    25.0                    28.4       1718       1905
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0_level_0_Player', 'Unnamed: 1_level_0_Nation',
#        'Unnamed: 2_level_0_Pos', 'Unnamed: 3_level_0_Age',
#        'Unnamed: 4_level_0_90s', 'Total_Cmp', 'Total_Att', 'Total_Cmp%',
#        'Total_TotDist', 'Total_PrgDist', 'Short_Cmp', 'Short_Att',
#        'Short_Cmp%', 'Medium_Cmp', 'Medium_Att', 'Medium_Cmp%', 'Long_Cmp',
#        'Long_Att', 'Long_Cmp%', 'Unnamed: 19_level_0_Ast',
#        'Unnamed: 20_level_0_xAG', 'Expected_xA', 'Expected_A-xAG',
#        'Unnamed: 23_level_0_KP', 'Unnamed: 24_level_0_1/3',
#        'Unnamed: 25_level_0_PPA', 'Unnamed: 26_level_0_CrsPA',
#        'Unnamed: 27_level_0_PrgP', 'Unnamed: 28_level_0_Matches'],
#       dtype='object')

# %%
df = df.rename(columns={
    # General info
    'Unnamed: 0_level_0_Player': 'Player',
    'Unnamed: 1_level_0_Nation': 'Nation',
    'Unnamed: 2_level_0_Pos': 'Position',
    'Unnamed: 3_level_0_Age': 'Age',
    'Unnamed: 4_level_0_90s': '90s Played',

    # Passing: Total
    'Total_Cmp': 'Total Passes Completed',
    'Total_Att': 'Total Passes Attempted',
    'Total_Cmp%': 'Total Pass Completion %',
    'Total_TotDist': 'Total Pass Distance',
    'Total_PrgDist': 'Total Progressive Pass Distance',

    # Passing: Short
    'Short_Cmp': 'Short Passes Completed',
    'Short_Att': 'Short Passes Attempted',
    'Short_Cmp%': 'Short Pass Completion %',

    # Passing: Medium
    'Medium_Cmp': 'Medium Passes Completed',
    'Medium_Att': 'Medium Passes Attempted',
    'Medium_Cmp%': 'Medium Pass Completion %',

    # Passing: Long
    'Long_Cmp': 'Long Passes Completed',
    'Long_Att': 'Long Passes Attempted',
    'Long_Cmp%': 'Long Pass Completion %',

    # Other metrics
    'Unnamed: 19_level_0_Ast': 'Assists',
    'Unnamed: 20_level_0_xAG': 'Expected Assisted Goals (xAG)',
    'Expected_xA': 'Expected Assists (xA)',
    'Expected_A-xAG': 'Assists Minus xAG',

    'Unnamed: 23_level_0_KP': 'Key Passes',
    'Unnamed: 24_level_0_1/3': 'Passes into Final Third',
    'Unnamed: 25_level_0_PPA': 'Passes into Penalty Area',
    'Unnamed: 26_level_0_CrsPA': 'Crosses into Penalty Area',
    'Unnamed: 27_level_0_PrgP': 'Progressive Passes',

    # Matches
    'Unnamed: 28_level_0_Matches': 'Matches'
})
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# %%
df.to_csv('./Data/clean/stg_passing.csv', index=False)

# %%
df=pd.read_csv('./Data/raw/stg_goalkeeping.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0_level_0_Player', 'Unnamed: 1_level_0_Nation',
#        'Unnamed: 2_level_0_Pos', 'Unnamed: 3_level_0_Age', 'Playing Time_MP',
#        'Playing Time_Starts', 'Playing Time_Min', 'Playing Time_90s',
#        'Performance_GA', 'Performance_GA90', 'Performance_SoTA',
#        'Performance_Saves', 'Performance_Save%', 'Performance_W',
#        'Performance_D', 'Performance_L', 'Performance_CS', 'Performance_CS%',
#        'Penalty Kicks_PKatt', 'Penalty Kicks_PKA', 'Penalty Kicks_PKsv',
#        'Penalty Kicks_PKm', 'Penalty Kicks_Save%',
#        'Unnamed: 23_level_0_Matches'],
#       dtype='object')

# %%
df = df.rename(columns={
    # Player Info
    'Unnamed: 0_level_0_Player': 'Player',
    'Unnamed: 1_level_0_Nation': 'Nation',
    'Unnamed: 2_level_0_Pos': 'Position',
    'Unnamed: 3_level_0_Age': 'Age',

    # Playing Time
    'Playing Time_MP': 'Matches Played',
    'Playing Time_Starts': 'Starts',
    'Playing Time_Min': 'Minutes Played',
    'Playing Time_90s': '90s Played',

    # Performance
    'Performance_GA': 'Goals Against',
    'Performance_GA90': 'GA per 90',
    'Performance_SoTA': 'Shots on Target Against',
    'Performance_Saves': 'Saves',
    'Performance_Save%': 'Save Percentage',
    'Performance_W': 'Wins',
    'Performance_D': 'Draws',
    'Performance_L': 'Losses',
    'Performance_CS': 'Clean Sheets',
    'Performance_CS%': 'Clean Sheet Percentage',

    # Penalty Kicks
    'Penalty Kicks_PKatt': 'PK Faced',
    'Penalty Kicks_PKA': 'PK Allowed',
    'Penalty Kicks_PKsv': 'PK Saves',
    'Penalty Kicks_PKm': 'PK Missed',
    'Penalty Kicks_Save%': 'PK Save Percentage',

    # Matches Column
    'Unnamed: 23_level_0_Matches': 'Matches'
})
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# %%
df.to_csv('./Data/clean/stg_goalkeeping.csv', index=False)

# %%
df=pd.read_csv('Data/raw/stg_advanced_goalkeeping.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0_level_0_Player', 'Unnamed: 1_level_0_Nation',
#        'Unnamed: 2_level_0_Pos', 'Unnamed: 3_level_0_Age',
#        'Unnamed: 4_level_0_90s', 'Goals_GA', 'Goals_PKA', 'Goals_FK',
#        'Goals_CK', 'Goals_OG', 'Expected_PSxG', 'Expected_PSxG/SoT',
#        'Expected_PSxG+/-', 'Expected_/90', 'Launched_Cmp', 'Launched_Att',
#        'Launched_Cmp%', 'Passes_Att (GK)', 'Passes_Thr', 'Passes_Launch%',
#        'Passes_AvgLen', 'Goal Kicks_Att', 'Goal Kicks_Launch%',
#        'Goal Kicks_AvgLen', 'Crosses_Opp', 'Crosses_Stp', 'Crosses_Stp%',
#        'Sweeper_#OPA', 'Sweeper_#OPA/90', 'Sweeper_AvgDist',
#        'Unnamed: 30_level_0_Matches'],
#       dtype='object')

# %%
df = df.rename(columns={
    # Player Info
    'Unnamed: 0_level_0_Player': 'Player',
    'Unnamed: 1_level_0_Nation': 'Nation',
    'Unnamed: 2_level_0_Pos': 'Position',
    'Unnamed: 3_level_0_Age': 'Age',
    'Unnamed: 4_level_0_90s': '90s Played',

    # Goals
    'Goals_GA': 'Goals Against',
    'Goals_PKA': 'Penalty Goals Allowed',
    'Goals_FK': 'Free Kick Goals Allowed',
    'Goals_CK': 'Corner Kick Goals Allowed',
    'Goals_OG': 'Own Goals',

    # Expected Goals
    'Expected_PSxG': 'Post-Shot xG',
    'Expected_PSxG/SoT': 'PSxG per SoT',
    'Expected_PSxG+/-': 'PSxG +/-',
    'Expected_/90': 'PSxG +/- per 90',

    # Launched Passes
    'Launched_Cmp': 'Launched Passes Completed',
    'Launched_Att': 'Launched Passes Attempted',
    'Launched_Cmp%': 'Launched Pass Completion %',

    # Passes
    'Passes_Att (GK)': 'Passes Attempted (GK)',
    'Passes_Thr': 'Throws',
    'Passes_Launch%': 'Launch % (Passes)',
    'Passes_AvgLen': 'Pass Avg Length',

    # Goal Kicks
    'Goal Kicks_Att': 'Goal Kicks Attempted',
    'Goal Kicks_Launch%': 'Launch % (Goal Kicks)',
    'Goal Kicks_AvgLen': 'Goal Kick Avg Length',

    # Crosses
    'Crosses_Opp': 'Opposition Crosses',
    'Crosses_Stp': 'Crosses Stopped',
    'Crosses_Stp%': 'Cross Stop %',

    # Sweeper Actions
    'Sweeper_#OPA': 'Sweeper OPA',
    'Sweeper_#OPA/90': 'OPA per 90',
    'Sweeper_AvgDist': 'OPA Avg Distance',

    # Matches Column
    'Unnamed: 30_level_0_Matches': 'Matches'
})
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# %%
df.to_csv('./Data/clean/stg_advanced_goalkeeping.csv', index=False)
